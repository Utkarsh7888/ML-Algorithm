# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  1.199509  4.100038 -0.071784  1.353084  1.138182       1
# 1 -0.101578  1.113150 -1.348872 -1.040210  1.147303       0
# 2 -3.306597 -2.490365 -0.094055 -0.122038  3.217932       0
# 3  2.427254  0.051497 -2.832326 -0.710977  1.078095       0
# 4 -1.188248 -1.016989 -1.662429  2.387707  2.450771       1

# %%
import random

# %%
def sample_rows(df,percent):
    return df.sample(int(percent*df.shape[0]),replace=True)

# %%
def sample_features(df,percent):
    cols = random.sample(df.columns.tolist()[:-1],int(percent*(df.shape[1]-1)))
    new_df = df[cols]
    new_df['target'] = df['target']
    return new_df

# %%
def combined_sampling(df,row_percent,col_percent):
    new_df = sample_rows(df,row_percent)
    return sample_features(new_df,col_percent)

# %%
df1 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13412\2564530682.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df2 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13412\2564530682.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df3 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13412\2564530682.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['col5', 'col4', 'target'], dtype='object')
# Index(['col1', 'col5', 'target'], dtype='object')
# Index(['col5', 'col2', 'target'], dtype='object')

# %% [markdown]
# ##

# %%
df3
# Out:
#         col5      col2  target
# 61  0.645177 -0.426744       0
# 97  1.815190 -2.232821       1
# 69  0.552278 -0.778168       1
# 75 -0.015951 -0.699289       0
# 16  1.334122  0.279510       0
# 33  1.127997 -1.605904       1
# 95 -0.568383 -0.991737       0
# 13 -1.037570 -1.222349       0
# 85  0.872724  1.239644       1
# 81  3.839600 -0.316189       0
# 30  0.336486  1.520533       1
# 6  -1.205074  0.743718       1
# 75 -0.015951 -0.699289       0
# 52  2.623421 -3.079266       0
# 89  1.426347 -4.360782       0
# 4   2.450771 -1.016989       1
# 46  1.014813  0.204084       1
# 30  0.336486  1.520533       1
# 94  0.190823  1.001702       0
# 73  1.262895  0.209385       1
# 87  3.068164 -2.669911       0
# 12  1.740753 -0.989722       0
# 95 -0.568383 -0.991737       0
# 80  0.032740  1.390355       0
# 40  2.167518 -0.925160       0
# 22  2.775665 -1.110722       0
# 81  3.839600 -0.316189       0
# 58 -0.593881 -0.926995       1
# 77  0.598404  1.507619       1
# 98  1.219635 -2.718468       1
# 10  1.184953  2.372387       1
# 90  1.202023 -0.727140       0
# 17 -0.189047  0.975259       1
# 13 -1.037570 -1.222349       0
# 43  0.439690  1.750238       1
# 78  0.445664  3.062447       1
# 29  1.013029  2.038563       1
# 91  1.869719 -0.675604       0
# 94  0.190823  1.001702       0
# 83  0.573612  0.505249       1
# 52  2.623421 -3.079266       0
# 83  0.573612  0.505249       1
# 1   1.147303  1.113150       0
# 14 -0.676402 -0.476742       0
# 94  0.190823  1.001702       0
# 50  0.819841  1.347546       1
# 49  2.094352 -1.740115       1
# 89  1.426347 -4.360782       0
# 25  1.559478  1.950971       1
# 59  4.923171 -0.910558       0

# %%
df2
# Out:
#         col1      col5  target
# 10  2.603416  1.184953       1
# 11 -0.842345  2.502916       0
# 77  1.598165  0.598404       1
# 8   1.171214 -0.820537       0
# 23  0.403283 -2.061003       0

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:2],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:2],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:2],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.6, 0.875, 'x[1] <= 0.196\ngini = 0.487\nsamples = 50\nvalue = [29, 21]'),
#  Text(0.4, 0.625, 'x[1] <= -0.71\ngini = 0.361\nsamples = 38\nvalue = [29, 9]'),
#  Text(0.2, 0.375, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.6, 0.375, 'x[0] <= 0.997\ngini = 0.49\nsamples = 21\nvalue = [12, 9]'),
#  Text(0.4, 0.125, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.8, 0.125, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.8, 0.625, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.32142857142857145, 0.9285714285714286, 'x[0] <= -0.665\ngini = 0.499\nsamples = 50\nvalue = [26, 24]'),
#  Text(0.14285714285714285, 0.7857142857142857, 'x[1] <= 1.25\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.09523809523809523, 0.6428571428571429, 'x[1] <= 0.602\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.047619047619047616, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14285714285714285, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19047619047619047, 0.6428571428571429, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.5, 0.7857142857142857, 'x[1] <= 0.117\ngini = 0.461\nsamples = 36\nvalue = [13, 23]'),
#  Text(0.2857142857142857, 0.6428571428571429, 'x[0] <= 0.856\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.23809523809523808, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.3333333333333333, 0.5, 'x[1] <= -0.972\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.2857142857142857, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.38095238095238093, 0.35714285714285715, 'x[0] <= 1.941\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3333333333333333, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.42857142857142855, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7142857142857143, 0.6428571428571429, 'x[1] <= 1.419\ngini = 0.355\nsamples = 26\nvalue = [6, 20]'),
#  Text(0.6190476190476191, 0.5, 'x[1] <= 0.707\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.5714285714285714, 0.35714285714285715, 'x[1] <= 0.624\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.5238095238095238, 0.21428571428571427, 'x[0] <= 1.657\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.47619047619047616, 0.07142857142857142, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5714285714285714, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6190476190476191, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.35714285714285715, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.8095238095238095, 0.5, 'x[1] <= 1.803\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.7619047619047619, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8571428571428571, 0.35714285714285715, 'x[1] <= 1.934\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.8095238095238095, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9047619047619048, 0.21428571428571427, 'x[1] <= 2.023\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8571428571428571, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9523809523809523, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.7241379310344828, 0.95, 'x[1] <= 1.176\ngini = 0.497\nsamples = 50\nvalue = [27, 23]'),
#  Text(0.5862068965517241, 0.85, 'x[0] <= 2.537\ngini = 0.444\nsamples = 39\nvalue = [26, 13]'),
#  Text(0.5172413793103449, 0.75, 'x[1] <= 0.988\ngini = 0.482\nsamples = 32\nvalue = [19, 13]'),
#  Text(0.4482758620689655, 0.65, 'x[1] <= -0.111\ngini = 0.497\nsamples = 28\nvalue = [15, 13]'),
#  Text(0.27586206896551724, 0.55, 'x[1] <= -1.414\ngini = 0.444\nsamples = 21\nvalue = [14, 7]'),
#  Text(0.13793103448275862, 0.45, 'x[1] <= -3.54\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.06896551724137931, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.20689655172413793, 0.35, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.41379310344827586, 0.45, 'x[0] <= 2.309\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(0.3448275862068966, 0.35, 'x[1] <= -0.753\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.27586206896551724, 0.25, 'x[1] <= -0.958\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.20689655172413793, 0.15, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.3448275862068966, 0.15, 'x[0] <= 1.36\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.27586206896551724, 0.05, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.41379310344827586, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.41379310344827586, 0.25, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4827586206896552, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6206896551724138, 0.55, 'x[0] <= 1.299\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.5517241379310345, 0.45, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6896551724137931, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5862068965517241, 0.65, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6551724137931034, 0.75, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8620689655172413, 0.85, 'x[0] <= 0.185\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.7931034482758621, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9310344827586207, 0.75, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]')]

# %%
clf1.predict(np.array([-1.042498,	-0.064323]).reshape(1,2))
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf2.predict(np.array([-1.042498,	-0.064323]).reshape(1,2))
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([-1.042498,	-0.064323]).reshape(1,2))
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
